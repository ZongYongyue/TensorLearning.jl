# %% [markdown]
# # Heisenberg Model

# %%
using LinearAlgebra
using TensorKit
using MPSKit
using MPSKitModels
using WignerSymbols

# %% [markdown]
# ## 1. MPSKitModels:

# %%
S_auto = S_exchange(ComplexF64, SU2Irrep; spin=1);

# %%
lattice = InfiniteChain(1)
H_auto = heisenberg_XXX(ComplexF64, SU2Irrep, lattice; J=1.0, spin=1);
SS1 = S_exchange(ComplexF64, SU2Irrep; spin=1);

# %%
function S_exchange(elt::Type{<:Number}, ::Type{SU2Irrep}; spin=1 // 2)
    pspace = SU2Space(spin => 1)
    aspace = SU2Space(1 => 1)

    Sleft = TensorMap(ones, elt, pspace ← pspace ⊗ aspace)
    Sright = -TensorMap(ones, elt, aspace ⊗ pspace ← pspace)

    @tensor SS[-1 -2; -3 -4] := Sleft[-1; -3 1] * Sright[1 -2; -4] * (spin^2 + spin)
    return SS
end

function heisenberg_XXX end
function heisenberg_XXX(lattice::AbstractLattice; kwargs...)
    return heisenberg_XXX(ComplexF64, Trivial, lattice; kwargs...)
end
function heisenberg_XXX(symmetry::Type{<:Sector}, lattice::AbstractLattice=InfiniteChain(1);
                        kwargs...)
    return heisenberg_XXX(ComplexF64, symmetry, lattice; kwargs...)
end
function heisenberg_XXX(elt::Type{<:Number}, lattice::AbstractLattice; kwargs...)
    return heisenberg_XXX(elt, Trivial, lattice; kwargs...)
end
function heisenberg_XXX(T::Type{<:Number}=ComplexF64,
                        symmetry::Type{<:Sector}=Trivial,
                        lattice::AbstractLattice=InfiniteChain(1);
                        J::Real=1.0, spin::Real=1)
    term = rmul!(S_exchange(T, symmetry; spin=spin), J)
    return @mpoham sum(nearest_neighbours(lattice)) do (i, j)
        return term{i,j}
    end
end

# %% [markdown]
# ##  2. quadratic Casimir:

# %%
casimir(s::SU2Irrep) = s.j * (s.j + 1)

function heisenberg_hamiltonian(; J=-1.0)
    s = SU2Irrep(1)
    ℋ = SU2Space(1 => 1)
    SS = TensorMap(zeros, ComplexF64, ℋ ⊗ ℋ ← ℋ ⊗ ℋ)
    for (S, data) in blocks(SS)
        data .= -0.5J * (casimir(S) - casimir(s) - casimir(s))
    end
    return SS, MPOHamiltonian(SS)
end
SS2 = heisenberg_hamiltonian()[1]
H_qC = heisenberg_hamiltonian()[2];

# %% [markdown]
# ## 3. Wigner-Eckart Theorem:

# %%
Sx = 1 / sqrt(2) * ComplexF64[0 1 0; 1 0 1; 0 1 0]
Sy = 1 / sqrt(2) * ComplexF64[0 1im 0; -1im 0 1im; 0 -1im 0]
Sz = ComplexF64[-1 0 0; 0 0 0; 0 0 1]

@tensor SS_arr[-1 -2; -3 -4] := Sx[-1; -3] * Sx[-2; -4] + Sy[-1; -3] * Sy[-2; -4] + Sz[-1; -3] * Sz[-2; -4];

# %%
function get_reduced_element(k)
    # construct Clebsch-Gordan coefficients for coupling 1 ⊗ 1 to k   
    CG = zeros(ComplexF64, 3, 3, 2*k + 1)
    for m1 in -k:k, m2 in -1:1, m3 in -1:1
        CG[m2 + 2, m3 + 2, m1 + k + 1] = clebschgordan(1, m2, 1, m3, k, m1)
    end

    # project out diagonal matrix on coupled irrep space
    @tensor reduced_matrix[-1; -2] := CG[1 2; -1] * SS_arr[1 2; 3 4] * conj(CG[3 4; -2])

    # check that it is proportional to the identity
    @assert isapprox(reduced_matrix, reduced_matrix[1, 1] * I; atol=1e-12)

    # return the proportionality factor
    return reduced_matrix[1, 1]
end

V = SU2Space(1 => 1)
SS = TensorMap(zeros, ComplexF64, V ⊗ V ← V ⊗ V)
for (s, f) in fusiontrees(SS)
    k = Int(f.coupled.j)
    SS[s, f] .= get_reduced_element(k)
end
SS3 = SS;

# %%
lattice = InfiniteChain(1)
H_WE = @mpoham begin
    sum(nearest_neighbours(lattice)) do (i, j)
        return SS{i,j}
    end
end;

# %% [markdown]
# ## Check

# %%
SS1 ≈ SS2 ≈ SS3
# Out:
# true

# %%
V = SU2Space(1 => 1)
SS4 = TensorMap(zeros, ComplexF64, V ⊗ V ← V ⊗ V)
blocks(SS4)[SU2Irrep(0)][1,1] = -2
blocks(SS4)[SU2Irrep(1)][1,1] = -1
blocks(SS4)[SU2Irrep(2)][1,1] = 1
SS4 ≈ SS3
# Out:
# true

# %%
H_qC ≈ H_auto ≈ H_WE
# Out:
# true

# %%
H = heisenberg_XXX(ComplexF64, SU2Irrep, InfiniteChain(2); spin=1//2);

# %%
P = Rep[SU₂](1//2 => 1)
V1 = Rep[SU₂](1//2 => 50, 3//2 => 25)
V2 = Rep[SU₂](0 => 80, 1 => 80, 2=> 40)
state = InfiniteMPS([P, P], [V1, V2]);

# %%
groundstate, cache, delta = find_groundstate(state, H, VUMPS(; maxiter=400, tol_galerkin=1e-12));
# Out:
# ┌ Info: VUMPS iteration:
# │   iter = 1
# │   ϵ = 0.08893768627027673
# │   λ = -0.8821389040993324 - 2.378501115724251e-16im
# │   Δt = 0.649920792
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 2
# │   ϵ = 0.009226516319418879
# │   λ = -0.8858077421906676 + 6.602946740391882e-17im
# │   Δt = 0.658653417
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 3
# │   ϵ = 0.0027106568266109196
# │   λ = -0.8861962494427349 - 2.0235565493835012e-16im
# │   Δt = 0.594616375
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 4
# │   ϵ = 0.0010954123441341173
# │   λ = -0.8862647364824582 - 6.845349702794832e-17im
# │   Δt = 0.624735917
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 5
# │   ϵ = 0.00047169332532036345
# │   λ = -0.8862804441401848 - 4.66177288015613e-17im
# │   Δt = 0.684608208
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 6
# │   ϵ = 0.00017778186419252818
# │   λ = -0.8862831408123943 + 2.7163923101971785e-17im
# │   Δt = 0.826014041
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 7
# │   ϵ = 7.135955597124798e-5
# │   λ = -0.8862834051686062 - 1.0155925037579061e-18im
# │   Δt = 0.821380542
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 8
# │   ϵ = 3.567446199383682e-5
# │   λ = -0.8862834217164 - 8.519033867010126e-19im
# │   Δt = 0.972912
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 9
# │   ϵ = 2.4516600898722362e-5
# │   λ = -0.8862834231668769 + 3.318304510427925e-17im
# │   Δt = 0.969722541
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 10
# │   ϵ = 1.5829722078433396e-5
# │   λ = -0.8862834235257707 + 5.719399393921531e-17im
# │   Δt = 1.058213042
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 11
# │   ϵ = 1.0264277114935208e-5
# │   λ = -0.8862834236413102 - 1.9572496191323525e-17im
# │   Δt = 0.970269209
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 12
# │   ϵ = 6.586225708338768e-6
# │   λ = -0.8862834236784832 + 1.2766120592014232e-16im
# │   Δt = 0.957820875
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 13
# │   ϵ = 6.197720089683363e-6
# │   λ = -0.8862834236864197 - 3.251897127363188e-17im
# │   Δt = 0.985078833
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 14
# │   ϵ = 6.7654819455628685e-6
# │   λ = -0.8862834236878903 - 2.6806686956467284e-17im
# │   Δt = 0.962373333
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 15
# │   ϵ = 7.990298286035134e-6
# │   λ = -0.8862834236862318 - 4.401606710406972e-17im
# │   Δt = 0.953226708
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 16
# │   ϵ = 9.494696787370459e-6
# │   λ = -0.8862834236829553 - 7.094006812373172e-17im
# │   Δt = 0.95873075
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 17
# │   ϵ = 1.1477029825827508e-5
# │   λ = -0.8862834236757237 + 1.2503900367367982e-16im
# │   Δt = 0.854779083
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 18
# │   ϵ = 1.3933970280924696e-5
# │   λ = -0.8862834236648265 + 3.2007257494371874e-17im
# │   Δt = 0.857480875
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 19
# │   ϵ = 1.5189327593296622e-5
# │   λ = -0.8862834236572854 + 1.0238764859820532e-16im
# │   Δt = 0.957436
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 20
# │   ϵ = 1.3398164573162846e-5
# │   λ = -0.8862834236713173 - 2.1211610823379003e-17im
# │   Δt = 0.96036325
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 21
# │   ϵ = 1.2376119618704353e-5
# │   λ = -0.8862834236787807 - 8.82109375693489e-18im
# │   Δt = 0.957070584
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 22
# │   ϵ = 9.741735773761519e-6
# │   λ = -0.8862834236907686 - 2.3773303153672024e-17im
# │   Δt = 0.881512875
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 23
# │   ϵ = 7.276989564642056e-6
# │   λ = -0.8862834236988836 + 1.2397457442655678e-16im
# │   Δt = 0.963505333
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 24
# │   ϵ = 5.325015666878582e-6
# │   λ = -0.8862834237032815 - 1.3531319568651926e-16im
# │   Δt = 0.981627166
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 25
# │   ϵ = 3.42474502832188e-6
# │   λ = -0.8862834237064696 + 1.2214146277980046e-16im
# │   Δt = 0.960222458
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 26
# │   ϵ = 2.2908883989002618e-6
# │   λ = -0.8862834237075881 - 1.0509476589763006e-16im
# │   Δt = 0.964049292
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 27
# │   ϵ = 1.5058091919378493e-6
# │   λ = -0.8862834237081214 - 5.255405333327466e-17im
# │   Δt = 0.981248708
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 28
# │   ϵ = 1.0053821662452457e-6
# │   λ = -0.8862834237083335 - 9.105482421997561e-17im
# │   Δt = 0.960788875
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 29
# │   ϵ = 6.616495543801286e-7
# │   λ = -0.8862834237084376 - 6.36908425237742e-17im
# │   Δt = 0.965120375
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 30
# │   ϵ = 4.4171979947156296e-7
# │   λ = -0.8862834237084793 - 1.0265557570733369e-16im
# │   Δt = 1.01425025
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 31
# │   ϵ = 2.9130810805550834e-7
# │   λ = -0.8862834237085002 + 6.969635905936639e-17im
# │   Δt = 0.891786125
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 32
# │   ϵ = 1.9508336517969452e-7
# │   λ = -0.8862834237085032 - 1.9009272220958618e-17im
# │   Δt = 0.987783375
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 33
# │   ϵ = 1.29032820706571e-7
# │   λ = -0.8862834237085022 + 2.8508111449705156e-17im
# │   Δt = 0.930458833
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 34
# │   ϵ = 8.682973696848699e-8
# │   λ = -0.886283423708513 - 2.6540718611029433e-17im
# │   Δt = 1.013280791
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 35
# │   ϵ = 5.769158400677673e-8
# │   λ = -0.8862834237085112 - 6.021604867634104e-17im
# │   Δt = 0.925581083
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 36
# │   ϵ = 3.910896196787421e-8
# │   λ = -0.8862834237085118 + 7.613343888158465e-18im
# │   Δt = 0.966183333
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 37
# │   ϵ = 2.6203883380599276e-8
# │   λ = -0.8862834237085149 - 1.5102597449544175e-18im
# │   Δt = 0.888346917
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 38
# │   ϵ = 1.7990836080793645e-8
# │   λ = -0.886283423708512 - 1.0957212911725709e-16im
# │   Δt = 0.966031666
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 39
# │   ϵ = 1.2263816437064275e-8
# │   λ = -0.8862834237085151 - 1.2075291108145465e-16im
# │   Δt = 0.962357875
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 40
# │   ϵ = 8.623554055065248e-9
# │   λ = -0.8862834237085142 + 2.265056098208645e-17im
# │   Δt = 1.226028625
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 41
# │   ϵ = 6.0842132808656046e-9
# │   λ = -0.8862834237085129 - 6.15553665846277e-17im
# │   Δt = 0.974571583
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 42
# │   ϵ = 4.462049298378572e-9
# │   λ = -0.8862834237085093 - 9.691909801161315e-18im
# │   Δt = 1.069569125
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 43
# │   ϵ = 3.3315389577087264e-9
# │   λ = -0.8862834237085142 + 4.979786106246837e-17im
# │   Δt = 0.990034083
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 44
# │   ϵ = 2.587618624816359e-9
# │   λ = -0.886283423708504 - 2.2268443243756353e-17im
# │   Δt = 0.977172
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 45
# │   ϵ = 2.063001397136121e-9
# │   λ = -0.886283423708516 + 9.084195425241876e-17im
# │   Δt = 1.055967584
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 46
# │   ϵ = 1.689930063037991e-9
# │   λ = -0.8862834237085085 + 9.803718150198882e-18im
# │   Δt = 1.00908
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 47
# │   ϵ = 1.417710321129049e-9
# │   λ = -0.8862834237085113 - 2.268460111865423e-17im
# │   Δt = 0.947982
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 48
# │   ϵ = 1.2019592346096866e-9
# │   λ = -0.8862834237085101 + 3.649679681261568e-17im
# │   Δt = 0.987913542
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 49
# │   ϵ = 1.0385231623707136e-9
# │   λ = -0.8862834237085129 - 1.689359567695419e-17im
# │   Δt = 0.879518167
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 50
# │   ϵ = 8.966320208722284e-10
# │   λ = -0.8862834237085117 + 4.6164513235221047e-17im
# │   Δt = 0.92543775
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 51
# │   ϵ = 7.867325826307041e-10
# │   λ = -0.8862834237085104 + 1.0842953461097024e-16im
# │   Δt = 0.9072145
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 52
# │   ϵ = 6.85798566992459e-10
# │   λ = -0.8862834237085055 - 1.7135603577896584e-16im
# │   Δt = 0.895838791
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 53
# │   ϵ = 6.069711667552493e-10
# │   λ = -0.8862834237085107 - 1.513700816302638e-17im
# │   Δt = 0.838958833
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 54
# │   ϵ = 5.322626272429371e-10
# │   λ = -0.8862834237085131 - 3.531439175780788e-17im
# │   Δt = 0.775181
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 55
# │   ϵ = 4.738197687296042e-10
# │   λ = -0.8862834237085071 - 2.9217078026557005e-17im
# │   Δt = 0.792082
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 56
# │   ϵ = 4.1738910645884043e-10
# │   λ = -0.8862834237085107 - 2.7886442205979703e-18im
# │   Δt = 0.887230958
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 57
# │   ϵ = 3.732622524127151e-10
# │   λ = -0.8862834237085184 + 8.932565939771516e-17im
# │   Δt = 0.86916775
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 58
# │   ϵ = 3.301275366822529e-10
# │   λ = -0.8862834237085158 + 1.0578382720022143e-17im
# │   Δt = 0.767939416
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 59
# │   ϵ = 2.964009932301395e-10
# │   λ = -0.8862834237085111 + 9.468293103086179e-17im
# │   Δt = 0.863538875
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 60
# │   ϵ = 2.6313915153669005e-10
# │   λ = -0.8862834237085133 - 2.8410014446501267e-18im
# │   Δt = 0.750580584
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 61
# │   ϵ = 2.3710284921076006e-10
# │   λ = -0.8862834237085089 + 4.559663058364624e-17im
# │   Δt = 0.845920666
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 62
# │   ϵ = 2.112576753729896e-10
# │   λ = -0.8862834237085118 - 1.0223105338208168e-17im
# │   Δt = 0.765823917
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 63
# │   ϵ = 1.9096861580577992e-10
# │   λ = -0.886283423708512 - 6.908321308467268e-17im
# │   Δt = 0.842051416
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 64
# │   ϵ = 1.7073914149093584e-10
# │   λ = -0.8862834237085094 + 9.276694250417257e-17im
# │   Δt = 0.8458785
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 65
# │   ϵ = 1.5478390302951044e-10
# │   λ = -0.8862834237085127 - 3.284253785948302e-17im
# │   Δt = 0.7585575
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 66
# │   ϵ = 1.3883529495130014e-10
# │   λ = -0.8862834237085115 + 4.247976109598723e-17im
# │   Δt = 0.781406167
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 67
# │   ϵ = 1.2617683653721416e-10
# │   λ = -0.8862834237085118 + 6.481337293712296e-17im
# │   Δt = 0.771857375
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 68
# │   ϵ = 1.135106072155537e-10
# │   λ = -0.8862834237085095 + 5.867243700908849e-17im
# │   Δt = 0.765292333
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 69
# │   ϵ = 1.0338239931189108e-10
# │   λ = -0.8862834237085075 + 3.8433114130039013e-17im
# │   Δt = 0.792162208
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 70
# │   ϵ = 9.325385950221852e-11
# │   λ = -0.8862834237085144 + 6.018068505079317e-17im
# │   Δt = 0.773632583
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 71
# │   ϵ = 8.508521332521258e-11
# │   λ = -0.886283423708511 + 8.482076760730236e-17im
# │   Δt = 0.7598345
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 72
# │   ϵ = 7.693309459773779e-11
# │   λ = -0.8862834237085118 - 1.5173060002843892e-17im
# │   Δt = 0.7527835
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 73
# │   ϵ = 7.029734560578138e-11
# │   λ = -0.8862834237085104 - 4.340212703598796e-17im
# │   Δt = 0.762946042
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 74
# │   ϵ = 6.369465928013527e-11
# │   λ = -0.8862834237085107 + 3.612224943125167e-18im
# │   Δt = 0.785638917
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 75
# │   ϵ = 5.826925225619191e-11
# │   λ = -0.8862834237085111 - 1.0575899854695504e-16im
# │   Δt = 0.767538416
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 76
# │   ϵ = 5.28926458301819e-11
# │   λ = -0.8862834237085071 + 3.535097299321743e-17im
# │   Δt = 0.774328417
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 77
# │   ϵ = 4.843269486212493e-11
# │   λ = -0.8862834237085151 + 4.100645316335678e-17im
# │   Δt = 0.8022795
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 78
# │   ϵ = 4.403265981923034e-11
# │   λ = -0.8862834237085081 + 2.318673283769842e-17im
# │   Δt = 0.77655975
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 79
# │   ϵ = 4.034964063819819e-11
# │   λ = -0.8862834237085075 + 1.8739142826167381e-16im
# │   Δt = 1.032254875
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 80
# │   ϵ = 3.6732799156084224e-11
# │   λ = -0.8862834237085104 + 9.538210378926102e-17im
# │   Δt = 1.116595292
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 81
# │   ϵ = 3.367806829173893e-11
# │   λ = -0.8862834237085104 + 4.543542962587191e-17im
# │   Δt = 0.791995125
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 82
# │   ϵ = 3.069406144071869e-11
# │   λ = -0.8862834237085098 - 9.823379902487023e-17im
# │   Δt = 0.737911917
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 83
# │   ϵ = 2.8154199679508722e-11
# │   λ = -0.8862834237085102 + 4.214745948286753e-17im
# │   Δt = 0.77432375
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 84
# │   ϵ = 2.5684201747575662e-11
# │   λ = -0.886283423708508 + 1.1768156961471056e-16im
# │   Δt = 0.759725166
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 85
# │   ϵ = 2.356537330406264e-11
# │   λ = -0.8862834237085074 + 4.121635851559824e-17im
# │   Δt = 0.743412833
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 86
# │   ϵ = 2.1516101993746142e-11
# │   λ = -0.8862834237085113 + 8.839529958427472e-18im
# │   Δt = 0.729113708
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 87
# │   ϵ = 1.974516535730127e-11
# │   λ = -0.8862834237085122 - 1.492874393712023e-17im
# │   Δt = 0.751615625
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 88
# │   ϵ = 1.804046173074987e-11
# │   λ = -0.8862834237085091 + 1.3733580448544412e-17im
# │   Δt = 0.770296041
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 89
# │   ϵ = 1.6558261079520427e-11
# │   λ = -0.8862834237085122 + 3.5468392935530555e-17im
# │   Δt = 0.753596375
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 90
# │   ϵ = 1.5137351287827363e-11
# │   λ = -0.8862834237085099 - 3.856678651702758e-17im
# │   Δt = 0.809222292
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 91
# │   ϵ = 1.3894650750464985e-11
# │   λ = -0.8862834237085118 + 2.226574332623698e-17im
# │   Δt = 0.989891083
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 92
# │   ϵ = 1.2708227425566676e-11
# │   λ = -0.8862834237085095 + 4.743755081538506e-18im
# │   Δt = 1.277473584
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 93
# │   ϵ = 1.1665959822331375e-11
# │   λ = -0.8862834237085122 + 3.782700911671936e-17im
# │   Δt = 0.816125708
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 94
# │   ϵ = 1.0674509037519748e-11
# │   λ = -0.8862834237085138 + 6.096715514231879e-17im
# │   Δt = 0.6665675
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 95
# │   ϵ = 9.798918839222643e-12
# │   λ = -0.8862834237085133 - 3.9575602757207454e-17im
# │   Δt = 0.749460333
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 96
# │   ϵ = 8.96896480157871e-12
# │   λ = -0.8862834237085088 - 6.252172529832645e-17im
# │   Δt = 0.876945208
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 97
# │   ϵ = 8.233185577151329e-12
# │   λ = -0.8862834237085103 - 2.8921939983998085e-18im
# │   Δt = 0.81136825
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 98
# │   ϵ = 7.538431991020517e-12
# │   λ = -0.8862834237085147 - 1.2107647766730579e-17im
# │   Δt = 0.799222084
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 99
# │   ϵ = 6.91981544298012e-12
# │   λ = -0.886283423708508 - 1.0518084562089478e-17im
# │   Δt = 0.664571208
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 100
# │   ϵ = 6.3371739919831986e-12
# │   λ = -0.8862834237085118 + 1.0147772345461738e-17im
# │   Δt = 0.763033666
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 101
# │   ϵ = 5.816936844024365e-12
# │   λ = -0.8862834237085113 + 1.1563323219001284e-17im
# │   Δt = 0.672627292
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 102
# │   ϵ = 5.328824616516177e-12
# │   λ = -0.886283423708513 - 1.130039360426171e-16im
# │   Δt = 0.662798709
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 103
# │   ϵ = 4.891527219391283e-12
# │   λ = -0.8862834237085129 + 1.4124523211393714e-16im
# │   Δt = 0.77330825
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 104
# │   ϵ = 4.481184610264316e-12
# │   λ = -0.8862834237085134 + 5.4345686835395113e-17im
# │   Δt = 0.679887
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 105
# │   ϵ = 4.11332850509889e-12
# │   λ = -0.88628342370851 - 5.4159816043032e-18im
# │   Δt = 0.780160583
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 106
# │   ϵ = 3.768962870244222e-12
# │   λ = -0.8862834237085129 - 7.329635496431557e-17im
# │   Δt = 0.710745042
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 107
# │   ϵ = 3.45929169342292e-12
# │   λ = -0.8862834237085095 + 5.397029242108385e-18im
# │   Δt = 0.693806375
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 108
# │   ϵ = 3.170400097499564e-12
# │   λ = -0.8862834237085122 + 4.0410777243200195e-17im
# │   Δt = 0.74337325
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 109
# │   ϵ = 2.9096632634748124e-12
# │   λ = -0.886283423708512 + 5.559791916879219e-17im
# │   Δt = 0.70980275
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 110
# │   ϵ = 2.6667594438530746e-12
# │   λ = -0.8862834237085129 - 3.750275431659857e-17im
# │   Δt = 0.771497083
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 111
# │   ϵ = 2.447123481918246e-12
# │   λ = -0.8862834237085107 + 3.642453431430305e-17im
# │   Δt = 0.736376375
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 112
# │   ϵ = 2.243361727111531e-12
# │   λ = -0.8862834237085118 - 8.552571077765476e-17im
# │   Δt = 0.64512925
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 113
# │   ϵ = 2.0593184210918697e-12
# │   λ = -0.886283423708509 + 2.667762031112941e-17im
# │   Δt = 0.665657167
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 114
# │   ϵ = 1.8875911868524665e-12
# │   λ = -0.8862834237085135 - 1.0952765988752624e-16im
# │   Δt = 0.678829
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 115
# │   ϵ = 1.732251542476187e-12
# │   λ = -0.8862834237085124 + 4.066589297900135e-17im
# │   Δt = 0.646051584
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 116
# │   ϵ = 1.5879590450804922e-12
# │   λ = -0.8862834237085118 - 2.6103226093772587e-17im
# │   Δt = 0.689222916
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 117
# │   ϵ = 1.4574753129518111e-12
# │   λ = -0.8862834237085111 - 6.189751495575923e-17im
# │   Δt = 0.678095
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 118
# │   ϵ = 1.336284510942688e-12
# │   λ = -0.8862834237085153 - 7.709217429875811e-18im
# │   Δt = 0.69504875
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 119
# │   ϵ = 1.2256110218237796e-12
# │   λ = -0.8862834237085163 + 5.72625506683837e-17im
# │   Δt = 0.690060209
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 120
# │   ϵ = 1.1241790552512366e-12
# │   λ = -0.8862834237085153 - 7.894452947528486e-18im
# │   Δt = 0.657776666
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 121
# │   ϵ = 1.0314830262396993e-12
# │   λ = -0.8862834237085105 + 5.327106672312542e-17im
# │   Δt = 0.716053375
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS iteration:
# │   iter = 122
# │   ϵ = 9.45740251475398e-13
# │   λ = -0.8862834237085147 - 5.040973648774119e-17im
# │   Δt = 0.700768333
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:90
# ┌ Info: VUMPS summary:
# │   ϵ = 9.45740251475398e-13
# │   λ = -0.8862834237085147 - 5.040973648774119e-17im
# │   Δt = 103.087173209
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:98

# %%
expectation_value(groundstate, H, cache)#1/4 - log(2)
# Out:
# 2-element PeriodicArray{ComplexF64, 1}:
#  -0.42769697369193055 + 7.752045533271357e-18im
#   -0.4585864500165841 - 5.816178202101255e-17im

# %%
groundstate, cache, delta = find_groundstate(state, H, IDMRG2(trscheme=truncbelow(1e-5)));
# Out:
# ┌ Info: idmrg iter 1 err 0.01616776517774077
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 2 err 0.011924192785993446
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 3 err 0.00923874607320577
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 4 err 0.007498996789628296
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 5 err 0.006293365648630694
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 6 err 0.00541207269091504
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 7 err 0.004741299617594525
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 8 err 0.004215523697651217
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 9 err 0.003792140079359177
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 10 err 0.0034429630404998273
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 11 err 0.003150798658855701
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 12 err 0.0029028484106930937
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 13 err 0.0026902436681920504
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 14 err 0.0025064699845102102
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 15 err 0.00234488416871357
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 16 err 0.0022021126822114887
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 17 err 0.0020751828690083246
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 18 err 0.001961257582195257
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 19 err 0.0018594052169911557
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 20 err 0.0017670812867339387
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 21 err 0.0016837718914901832
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 22 err 0.0016076662130065558
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 23 err 0.0015379329906530209
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 24 err 0.0014734450359618196
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 25 err 0.00141378329975341
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 26 err 0.0013584183206973052
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 27 err 0.001306898851237676
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 28 err 0.0012594139782434797
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 29 err 0.0012153441263504337
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 30 err 0.00117479443570398
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 31 err 0.00113625690917707
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 32 err 0.0010998502920041226
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 33 err 0.001066450223844032
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 34 err 0.001034821671030346
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 35 err 0.0010047601627932645
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 36 err 0.0009764849585074643
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 37 err 0.0009492126308873001
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 38 err 0.0009235086735600705
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 39 err 0.0008991101743274565
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 40 err 0.0008755984513820676
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 41 err 0.0008535220146378684
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 42 err 0.0008321250395873467
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 43 err 0.0008117659928097674
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 44 err 0.0007921966977860719
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 45 err 0.0007734356964703387
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 46 err 0.0007559620367488729
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 47 err 0.0007387422952835222
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 48 err 0.0007225088962330886
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 49 err 0.0007071489616010681
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 50 err 0.0006920424896030517
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 51 err 0.0006774509386366302
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 52 err 0.0006646921110329992
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 53 err 0.0006518145893619634
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 54 err 0.0006389527150200717
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 55 err 0.000626485143050857
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 56 err 0.0006144110135967243
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 57 err 0.0006030851429298571
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 58 err 0.0005920259639639908
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 59 err 0.0005811790830835313
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 60 err 0.0005706495017071507
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 61 err 0.0005604272091367371
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 62 err 0.0005507245023817286
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 63 err 0.000541397722843318
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 64 err 0.0005322179707861656
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 65 err 0.0005232671042761026
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 66 err 0.0005147116904168271
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 67 err 0.0005062922978936219
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 68 err 0.00049807110643116
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 69 err 0.0004900504398962897
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 70 err 0.00048247486810862745
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 71 err 0.0004749092964598956
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 72 err 0.0004675139174458659
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 73 err 0.00046029046700105943
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 74 err 0.0004533256930343312
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 75 err 0.000447118650559588
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 76 err 0.0004407358121586094
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 77 err 0.0004342733348743259
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 78 err 0.0004279363998518802
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 79 err 0.00042207770588690316
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 80 err 0.000417780968500862
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 81 err 0.00041283482279915053
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 82 err 0.00040727453910135314
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 83 err 0.0004017927648921754
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 84 err 0.0003964080897111166
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 85 err 0.00039168088663975266
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 86 err 0.000386914442004105
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 87 err 0.0003818522081826468
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 88 err 0.0003769021129331788
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 89 err 0.0003726437238727213
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 90 err 0.00036799827369775274
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 91 err 0.00036339569621029436
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 92 err 0.0003588696015093344
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 93 err 0.0003544232404554728
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 94 err 0.0003500563295221317
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 95 err 0.0003457677703483311
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 96 err 0.0003415561276394037
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 97 err 0.000337419828960193
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 98 err 0.00033430416777918784
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 99 err 0.00033036069975187984
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178
# ┌ Info: idmrg iter 100 err 0.00032675705542769347
# └ @ MPSKit /Users/zongyy/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/idmrg.jl:178

# %%
expectation_value(groundstate, H, cache)
# Out:
# 2-element PeriodicArray{ComplexF64, 1}:
#  -0.4359499148565782 - 1.0447799605332413e-18im
#  -0.4503440875385665 - 4.990152404381441e-18im

# %%
H = heisenberg_XXX(ComplexF64, SU2Irrep, FiniteChain(12); spin=1//2);
P = Rep[SU₂](1//2 => 1)
V1 = Rep[SU₂](1//2 => 50, 3//2 => 25)
V2 = Rep[SU₂](0 => 80, 1 => 80, 2=> 40)
state = FiniteMPS([P, P], [V1, V2]);
groundstate, cache, delta = find_groundstate(state, H, VUMPS(; maxiter=400, tol_galerkin=1e-12));
